# %%
import pandas as pd
marathon_2015 = pd.read_csv('./marathon_results_2015.csv')
marathon_2016 = pd.read_csv('./marathon_results_2016.csv')
marathon_2017 = pd.read_csv('./marathon_results_2017.csv')

# %%
marathon_2017.head()
# Out:
#    Unnamed: 0 Bib              Name  Age M/F           City State Country  \
# 0           0  11   Kirui, Geoffrey   24   M       Keringet   NaN     KEN
# 1           1  17       Rupp, Galen   30   M       Portland    OR     USA
# 2           2  23     Osako, Suguru   25   M   Machida-City   NaN     JPN
# 3           3  21  Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA
# 4           4   9    Chebet, Wilson   31   M       Marakwet   NaN     KEN
#
#   Citizen Unnamed: 9  ...      25K      30K      35K      40K     Pace  \
# 0     NaN        NaN  ...  1:16:59  1:33:01  1:48:19  2:02:53  0:04:57
# 1     NaN        NaN  ...  1:16:59  1:33:01  1:48:19  2:03:14  0:04:58
# 2     NaN        NaN  ...  1:17:00  1:33:01  1:48:31  2:03:38  0:04:59
# 3     NaN        NaN  ...  1:17:00  1:33:01  1:48:58  2:04:35  0:05:03
# 4     NaN        NaN  ...  1:16:59  1:33:01  1:48:41  2:05:00  0:05:04
#
#   Proj Time Official Time Overall Gender Division
# ...

# %%
marathon_2015['Year'] = '2015'
marathon_2016['Year'] = '2016'
marathon_2017['Year'] = '2017'

# %%
marathon_2015_2017 = pd.concat([marathon_2015, marathon_2016, marathon_2017], ignore_index = True, sort=False)

# %%
marathon_2015_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79638 entries, 0 to 79637
# Data columns (total 27 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     53008 non-null  float64
#  1   Bib            79638 non-null  object
#  2   Name           79638 non-null  object
#  3   Age            79638 non-null  int64
#  4   M/F            79638 non-null  object
#  5   City           79637 non-null  object
#  6   State          70645 non-null  object
#  7   Country        79638 non-null  object
#  8   Citizen        3440 non-null   object
#  9   Unnamed: 9     158 non-null    object
#  10  5K             79638 non-null  object
#  11  10K            79638 non-null  object
#  12  15K            79638 non-null  object
#  13  20K            79638 non-null  object
#  14  Half           79638 non-null  object
#  15  25K            79638 non-null  object
#  16  30K            79638 non-null  object
# ...

# %%
marathon_2015_2017 = marathon_2015_2017.drop(['Unnamed: 0','Bib','Citizen','Unnamed: 9', 'Proj Time','Unnamed: 8'], axis=1)

# %%
marathon_2015_2017
# Out:
#                            Name  Age M/F          City State Country       5K  \
# 0                Desisa, Lelisa   25   M          Ambo   NaN     ETH  0:14:43
# 1         Tsegay, Yemane Adhane   30   M   Addis Ababa   NaN     ETH  0:14:43
# 2                Chebet, Wilson   29   M      Marakwet   NaN     KEN  0:14:43
# 3              Kipyego, Bernard   28   M       Eldoret   NaN     KEN  0:14:43
# 4                 Korir, Wesley   32   M        Kitale   NaN     KEN  0:14:43
# ...                         ...  ...  ..           ...   ...     ...      ...
# 79633  Steinbach, Paula Eyvonne   61   F       Ontario    CA     USA  0:46:44
# 79634        Avelino, Andrew R.   25   M  Fayetteville    NC     USA  0:32:03
# 79635           Hantel, Johanna   57   F       Malvern    PA     USA  0:53:11
# 79636              Reilly, Bill   64   M      New York    NY     USA  0:40:34
# 79637             Rigsby, Scott   48   M    Alpharetta    GA     USA  0:39:36
#
# ...

# %%
marathon_2015_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79638 entries, 0 to 79637
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           79638 non-null  object
#  1   Age            79638 non-null  int64
#  2   M/F            79638 non-null  object
#  3   City           79637 non-null  object
#  4   State          70645 non-null  object
#  5   Country        79638 non-null  object
#  6   5K             79638 non-null  object
#  7   10K            79638 non-null  object
#  8   15K            79638 non-null  object
#  9   20K            79638 non-null  object
#  10  Half           79638 non-null  object
#  11  25K            79638 non-null  object
#  12  30K            79638 non-null  object
#  13  35K            79638 non-null  object
#  14  40K            79638 non-null  object
#  15  Pace           79638 non-null  object
#  16  Official Time  79638 non-null  object
# ...

# %%
marathon_2015_2017.to_csv('./marathon_2015_2017.csv', index=None, header=True)

# %%
import pandas as pd
marathon_2015_2017 = pd.read_csv('./marathon_2015_2017.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
marathon_2015_2017.head()
# Out:
#                     Name  Age M/F         City State Country       5K  \
# 0         Desisa, Lelisa   25   M         Ambo   NaN     ETH  0:14:43
# 1  Tsegay, Yemane Adhane   30   M  Addis Ababa   NaN     ETH  0:14:43
# 2         Chebet, Wilson   29   M     Marakwet   NaN     KEN  0:14:43
# 3       Kipyego, Bernard   28   M      Eldoret   NaN     KEN  0:14:43
# 4          Korir, Wesley   32   M       Kitale   NaN     KEN  0:14:43
#
#        10K      15K      20K  ...      25K      30K      35K      40K  \
# 0  0:29:43  0:44:57  1:00:29  ...  1:16:07  1:32:00  1:47:59  2:02:39
# 1  0:29:43  0:44:58  1:00:28  ...  1:16:07  1:31:59  1:47:59  2:02:42
# 2  0:29:43  0:44:57  1:00:29  ...  1:16:07  1:32:00  1:47:59  2:03:01
# 3  0:29:44  0:45:01  1:00:29  ...  1:16:07  1:32:00  1:48:03  2:03:47
# 4  0:29:44  0:44:58  1:00:28  ...  1:16:07  1:32:00  1:47:59  2:03:27
#
#       Pace Official Time Overall  Gender  Division  Year
# 0  0:04:56       2:09:17       1       1         1  2015
# ...

# %%
USA_runner = marathon_2015_2017[marathon_2015_2017.Country == 'USA']
USA_runner.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64474 entries, 6 to 79637
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           64474 non-null  object
#  1   Age            64474 non-null  int64
#  2   M/F            64474 non-null  object
#  3   City           64474 non-null  object
#  4   State          64474 non-null  object
#  5   Country        64474 non-null  object
#  6   5K             64474 non-null  object
#  7   10K            64474 non-null  object
#  8   15K            64474 non-null  object
#  9   20K            64474 non-null  object
#  10  Half           64474 non-null  object
#  11  25K            64474 non-null  object
#  12  30K            64474 non-null  object
#  13  35K            64474 non-null  object
#  14  40K            64474 non-null  object
#  15  Pace           64474 non-null  object
#  16  Official Time  64474 non-null  object
# ...

# %%
plt.figure(figsize=(300,20))

# %%
runner_state = sns.countplot(x='State', data=USA_runner)
runner_state.set_title('Number of Runner by State - USA', fontsize=18)
runner_state.set_xlabel('State', fontdict={'size':16})
runner_state.set_ylabel('Number of Runner', fontdict={'size':16})
plt.show()

# %%
plt.figure(figsize=(30,20))
runner_state = sns.countplot(x='State', data=USA_runner, hue='M/F', palette={'F':'r','M':'b'})
runner_state.set_title('Number of Runner by State, Gender - USA', fontsize=18)
runner_state.set_xlabel('State', fontdict={'size':16})
runner_state.set_ylabel('Number of Runner', fontdict={'size':16})
plt.show()

# %%
plt.figure(figsize=(30,20))
runner_state = sns.countplot(x='State', data=USA_runner, hue='Year')
runner_state.set_title('Number of Runner by State, year - USA', fontsize=18)
runner_state.set_xlabel('State', fontdict={'size':16})
runner_state.set_ylabel('Number of Runner', fontdict={'size':16})
plt.show()

# %%
import pandas as pd
marathon_2015_2017 = pd.read_csv('./marathon_2015_2017.csv')
import matplotlib.pyplot as plt

# %%
runner_1860 = marathon_2015_2017[marathon_2015_2017.Age.isin(range(18,60))]
runner_1860_counting = runner_1860['Age'].value_counts()

# %%
runner_1860.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73608 entries, 0 to 79637
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           73608 non-null  object
#  1   Age            73608 non-null  int64
#  2   M/F            73608 non-null  object
#  3   City           73607 non-null  object
#  4   State          65438 non-null  object
#  5   Country        73608 non-null  object
#  6   5K             73608 non-null  object
#  7   10K            73608 non-null  object
#  8   15K            73608 non-null  object
#  9   20K            73608 non-null  object
#  10  Half           73608 non-null  object
#  11  25K            73608 non-null  object
#  12  30K            73608 non-null  object
#  13  35K            73608 non-null  object
#  14  40K            73608 non-null  object
#  15  Pace           73608 non-null  object
#  16  Official Time  73608 non-null  object
# ...

# %%
runner_1860_counting
# Out:
# 45    3236
# 46    3039
# 40    2734
# 47    2566
# 50    2498
# 41    2494
# 35    2327
# 42    2318
# 48    2277
# 43    2265
# 36    2188
# 38    2128
# 51    2124
# 37    2108
# 39    2101
# 44    2056
# 49    2018
# 52    1930
# 55    1920
# 29    1906
# 30    1849
# 33    1834
# 31    1779
# 28    1758
# 34    1756
# 27    1755
# 53    1730
# 32    1726
# 26    1709
# 25    1539
# 56    1514
# 54    1433
# 24    1301
# 57    1287
# 58    1044
# 23     920
# 59     788
# 22     701
# 21     489
# 20     264
# 19     137
# 18      62
# Name: Age, dtype: int64

# %%
x = runner_1860_counting.index
x = [str(i) for i in x]
y = runner_1860_counting.values

ratio = y/y.sum()
ratio_sum = ratio.cumsum()

# %%
fig, barChart = plt.subplots(figsize=(20,10))
barChart.bar(x,y)
lineChart = barChart.twinx()
lineChart.plot(x, ratio_sum, '-ro', alpha=0.5)
ranges = lineChart.get_yticks()
lineChart.set_yticklabels(['{0:01%}.format(x) for x in ranges'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13704\3222503487.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   lineChart.set_yticklabels(['{0:01%}.format(x) for x in ranges'])
# [Text(1, -0.2, '{0:01%}.format(x) for x in ranges'),
#  Text(1, 0.0, ''),
#  Text(1, 0.2, ''),
#  Text(1, 0.4000000000000001, ''),
#  Text(1, 0.6000000000000001, ''),
#  Text(1, 0.8, ''),
#  Text(1, 1.0000000000000002, ''),
#  Text(1, 1.2000000000000002, '')]

# %%
marathon_2015_2017 = pd.read_csv('./marathon_2015_2017.csv')

# %%
labels = 'Male','Female'

# %%
explode = (0, 0.1)

# %%
plt.figure(figsize=(7,7))
plt.pie(marathon_2015_2017['M/F'].value_counts(), explode=explode, labels=labels, startangle = 90, shadow=True, autopct='%.1f')
plt.title('Male vs Female', fontsize=18)
plt.show()

# %%
import pandas as pd
marathon_2015_2017 = pd.read_csv('./marathon_2015_2017.csv')
import matplotlib.pyplot as plt
record = pd.DataFrame(marathon_2015_2017, columns=['5K','10K','20K','Half','25K','30K','35K','40K','Official Time']).sort_values(by=['Official Time'])

# %%
record.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79638 entries, 53227 to 53226
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   5K             79638 non-null  object
#  1   10K            79638 non-null  object
#  2   20K            79638 non-null  object
#  3   Half           79638 non-null  object
#  4   25K            79638 non-null  object
#  5   30K            79638 non-null  object
#  6   35K            79638 non-null  object
#  7   40K            79638 non-null  object
#  8   Official Time  79638 non-null  object
# dtypes: object(9)
# memory usage: 6.1+ MB

# %%
record.head()
# Out:
#             5K      10K      20K     Half      25K      30K      35K      40K  \
# 53227  0:44:52  1:35:31  4:29:40  4:47:17        -  7:36:38        -        -
# 0      0:14:43  0:29:43  1:00:29  1:04:02  1:16:07  1:32:00  1:47:59  2:02:39
# 53228  0:15:25  0:30:28  1:01:15  1:04:35  1:16:59  1:33:01  1:48:19  2:02:53
# 1      0:14:43  0:29:43  1:00:28  1:04:01  1:16:07  1:31:59  1:47:59  2:02:42
# 53229  0:15:24  0:30:27  1:01:15  1:04:35  1:16:59  1:33:01  1:48:19  2:03:14
#
#       Official Time
# 53227      10:30:23
# 0           2:09:17
# 53228       2:09:37
# 1           2:09:48
# 53229       2:09:58

# %%
record.insert(0,'Rank',range(1,1+len(record)))

# %%
record.head()
# Out:
#        Rank       5K      10K      20K     Half      25K      30K      35K  \
# 53227     1  0:44:52  1:35:31  4:29:40  4:47:17        -  7:36:38        -
# 0         2  0:14:43  0:29:43  1:00:29  1:04:02  1:16:07  1:32:00  1:47:59
# 53228     3  0:15:25  0:30:28  1:01:15  1:04:35  1:16:59  1:33:01  1:48:19
# 1         4  0:14:43  0:29:43  1:00:28  1:04:01  1:16:07  1:31:59  1:47:59
# 53229     5  0:15:24  0:30:27  1:01:15  1:04:35  1:16:59  1:33:01  1:48:19
#
#            40K Official Time
# 53227        -      10:30:23
# 0      2:02:39       2:09:17
# 53228  2:02:53       2:09:37
# 1      2:02:42       2:09:48
# 53229  2:03:14       2:09:58

# %%
top100 = record[0:100]

# %%
xData = top100.Rank

# %%
xData
# Out:
# 53227      1
# 0          2
# 53228      3
# 1          4
# 53229      5
#         ...
# 39        96
# 41        97
# 40        98
# 42        99
# 53265    100
# Name: Rank, Length: 100, dtype: int64

# %%
yData_final = top100['Official Time']
yData_10K = top100['10K']
yData_20K = top100['20K']
yData_30K = top100['30K']

yData_final
# Out:
# 53227    10:30:23
# 0         2:09:17
# 53228     2:09:37
# 1         2:09:48
# 53229     2:09:58
#            ...
# 39        2:25:39
# 41        2:25:47
# 40        2:25:47
# 42        2:25:58
# 53265     2:26:00
# Name: Official Time, Length: 100, dtype: object

# %%
plt.figure(figsize=(20,10))
plt.plot(xData, yData_10K)
plt.plot(xData, yData_20K)
plt.plot(xData, yData_30K)
plt.plot(xData, yData_final)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
plt.plot(xData, yData_10K, 'r--')

plt.subplot(2,2,2)
plt.plot(xData, yData_20K, 'g:')

plt.subplot(2,2,3)
plt.plot(xData, yData_30K, 'y--')

plt.subplot(2,2,4)
plt.plot(xData, yData_final, 'b-.')

plt.show()

# %%
import pandas as pd
marathon_2015_2017 = pd.read_csv('./marathon_2015_2017.csv')
import matplotlib.pyplot as plt

# %%
MALE_runner = marathon_2015_2017[marathon_2015_2017['M/F'] == 'M']
FEMALE_runner = marathon_2015_2017[marathon_2015_2017['M/F'] == 'F']

# %%
FEMALE_runner.head()
# Out:
#                 Name  Age M/F             City State Country       5K  \
# 30  Rotich, Caroline   30   F        Nyahururu   NaN     KEN  0:16:59
# 31      Dibaba, Mare   25   F             Shoa   NaN     ETH  0:16:58
# 33    Deba, Buzunesh   27   F             Arsi   NaN     ETH  0:16:57
# 39   Linden, Desiree   31   F  Rochester Mills    MI     USA  0:17:00
# 43    Cherop, Sharon   31   F         Marakwet   NaN     KEN  0:16:59
#
#         10K      15K      20K  ...      25K      30K      35K      40K  \
# 30  0:34:24  0:51:49  1:09:00  ...  1:26:08  1:43:24  2:00:50  2:17:30
# 31  0:34:23  0:51:48  1:09:00  ...  1:26:08  1:43:23  2:00:50  2:17:30
# 33  0:34:23  0:51:49  1:09:01  ...  1:26:09  1:43:24  2:00:50  2:17:30
# 39  0:34:24  0:51:48  1:09:00  ...  1:26:08  1:43:23  2:00:49  2:17:51
# 43  0:34:24  0:51:49  1:09:01  ...  1:26:09  1:43:24  2:00:50  2:18:02
#
#        Pace Official Time Overall  Gender  Division  Year
# 30  0:05:32       2:24:55      31       1         1  2015
# ...

# %%
plt.figure(figsize=(20,20))
x_male = MALE_runner.Age
y_male = MALE_runner['Official Time']
x_female = FEMALE_runner.Age
y_female = FEMALE_runner['Official Time']

# %%
x_male
# Out:
# 0        25
# 1        30
# 2        29
# 3        28
# 4        32
#          ..
# 79631    25
# 79632    19
# 79634    25
# 79636    64
# 79637    48
# Name: Age, Length: 43482, dtype: int64

# %%
y_male
# Out:
# 0        2:09:17
# 1        2:09:48
# 2        2:10:22
# 3        2:10:47
# 4        2:10:49
#           ...
# 79631    6:56:11
# 79632    7:04:33
# 79634    7:16:59
# 79636    7:20:44
# 79637    7:58:14
# Name: Official Time, Length: 43482, dtype: object

# %%
plt.figure(figsize=(20,20))
plt.plot(x_male, y_male, '.b', alpha=0.5)
plt.plot(x_female, y_female, '.r', alpha=0.5)

plt.xlabel('Age', fontsize=16)
plt.ylabel('Official Time (Second)', fontsize=16)
plt.title('Distribution by Running Time and Age', fontsize=20)

plt.show()
