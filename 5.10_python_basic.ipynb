# %%
import pandas as pd

# %%
data = {'a': 100, 'b': 200, 'c': 300}
pd.DataFrame(data, index=['x','y','z'])
# Out:
#      a    b    c
# x  100  200  300
# y  100  200  300
# z  100  200  300

# %%
data = {'a': [1,2,3], 'b': [4,5,6], 'c': [10,11,12]}
pd.DataFrame(data, index=[0,1,2])
# Out:
#    a  b   c
# 0  1  4  10
# 1  2  5  11
# 2  3  6  12

# %%
a = pd.Series([100,200,300], ['a', 'b','c'])
b = pd.Series([101,201,301], ['a', 'b','c'])
c = pd.Series([110,210,310], ['a', 'b','c'])

pd.DataFrame([a,b,c], index=[100,101,102])
# Out:
#        a    b    c
# 100  100  200  300
# 101  101  201  301
# 102  110  210  310

# %%
a = pd.Series([100,200,300], ['a', 'b','d'])
b = pd.Series([101,201,301], ['a', 'b','k'])
c = pd.Series([110,210,310], ['a', 'b','c'])

pd.DataFrame([a,b,c], index=[100,101,102])
# Out:
#          a      b      d      k      c
# 100  100.0  200.0  300.0    NaN    NaN
# 101  101.0  201.0    NaN  301.0    NaN
# 102  110.0  210.0    NaN    NaN  310.0

# %%
marathon_2017 = pd.read_csv("./marathon_results_2017.csv", sep=',', header=None)
marathon_2017.head()
# Out:
#     0    1                 2    3    4              5      6        7   \
# 0  NaN  Bib              Name  Age  M/F           City  State  Country
# 1  0.0   11   Kirui, Geoffrey   24    M       Keringet    NaN      KEN
# 2  1.0   17       Rupp, Galen   30    M       Portland     OR      USA
# 3  2.0   23     Osako, Suguru   25    M   Machida-City    NaN      JPN
# 4  3.0   21  Biwott, Shadrack   32    M  Mammoth Lakes     CA      USA
#
#         8    9   ...       15       16       17       18       19         20  \
# 0  Citizen  NaN  ...      25K      30K      35K      40K     Pace  Proj Time
# 1      NaN  NaN  ...  1:16:59  1:33:01  1:48:19  2:02:53  0:04:57          -
# 2      NaN  NaN  ...  1:16:59  1:33:01  1:48:19  2:03:14  0:04:58          -
# 3      NaN  NaN  ...  1:17:00  1:33:01  1:48:31  2:03:38  0:04:59          -
# 4      NaN  NaN  ...  1:17:00  1:33:01  1:48:58  2:04:35  0:05:03          -
#
#               21       22      23        24
# ...

# %%
marathon_2017 = pd.read_csv("./marathon_results_2017.csv", index_col='Age', usecols=['Age','5K','10K','15K','20K','Half','25K','30K',
                                                                                     '35K','40K','Official Time'])
marathon_2017
# Out:
#           5K      10K      15K      20K     Half      25K      30K      35K  \
# Age
# 24   0:15:25  0:30:28  0:45:44  1:01:15  1:04:35  1:16:59  1:33:01  1:48:19
# 30   0:15:24  0:30:27  0:45:44  1:01:15  1:04:35  1:16:59  1:33:01  1:48:19
# 25   0:15:25  0:30:29  0:45:44  1:01:16  1:04:36  1:17:00  1:33:01  1:48:31
# 32   0:15:25  0:30:29  0:45:44  1:01:19  1:04:45  1:17:00  1:33:01  1:48:58
# 31   0:15:25  0:30:28  0:45:44  1:01:15  1:04:35  1:16:59  1:33:01  1:48:41
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 61   0:46:44  1:35:41  2:23:35  3:12:44  3:23:31  4:12:06  5:03:08  5:55:18
# 25   0:32:03  1:05:33  1:52:17  2:49:41  3:00:26  3:50:19  4:50:01  5:53:48
# 57   0:53:11  1:43:36  2:32:36        -  3:36:24  4:15:21  5:06:37  6:00:33
# 64   0:40:34  1:27:19  2:17:17  3:11:40  3:22:30  4:06:10  5:07:09  6:06:07
# 48   0:39:36  1:17:12  2:00:10  2:58:55  3:08:16  4:27:14  5:37:13  6:39:07
#
#          40K Official Time
# Age
# ...

# %%
marathon_2017 = pd.read_csv("./marathon_results_2017.csv")
marathon_2017.head()
# Out:
#    Unnamed: 0 Bib              Name  Age M/F           City State Country  \
# 0           0  11   Kirui, Geoffrey   24   M       Keringet   NaN     KEN
# 1           1  17       Rupp, Galen   30   M       Portland    OR     USA
# 2           2  23     Osako, Suguru   25   M   Machida-City   NaN     JPN
# 3           3  21  Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA
# 4           4   9    Chebet, Wilson   31   M       Marakwet   NaN     KEN
#
#   Citizen Unnamed: 9  ...      25K      30K      35K      40K     Pace  \
# 0     NaN        NaN  ...  1:16:59  1:33:01  1:48:19  2:02:53  0:04:57
# 1     NaN        NaN  ...  1:16:59  1:33:01  1:48:19  2:03:14  0:04:58
# 2     NaN        NaN  ...  1:17:00  1:33:01  1:48:31  2:03:38  0:04:59
# 3     NaN        NaN  ...  1:17:00  1:33:01  1:48:58  2:04:35  0:05:03
# 4     NaN        NaN  ...  1:16:59  1:33:01  1:48:41  2:05:00  0:05:04
#
#   Proj Time Official Time Overall Gender Division
# ...

# %%
marathon_2017.index
# Out:
# RangeIndex(start=0, stop=26410, step=1)

# %%
marathon_2017.columns
# Out:
# Index(['Unnamed: 0', 'Bib', 'Name', 'Age', 'M/F', 'City', 'State', 'Country',
#        'Citizen', 'Unnamed: 9', '5K', '10K', '15K', '20K', 'Half', '25K',
#        '30K', '35K', '40K', 'Pace', 'Proj Time', 'Official Time', 'Overall',
#        'Gender', 'Division'],
#       dtype='object')

# %%
marathon_2017.head(n=3)
# Out:
#    Unnamed: 0 Bib             Name  Age M/F          City State Country  \
# 0           0  11  Kirui, Geoffrey   24   M      Keringet   NaN     KEN
# 1           1  17      Rupp, Galen   30   M      Portland    OR     USA
# 2           2  23    Osako, Suguru   25   M  Machida-City   NaN     JPN
#
#   Citizen Unnamed: 9  ...      25K      30K      35K      40K     Pace  \
# 0     NaN        NaN  ...  1:16:59  1:33:01  1:48:19  2:02:53  0:04:57
# 1     NaN        NaN  ...  1:16:59  1:33:01  1:48:19  2:03:14  0:04:58
# 2     NaN        NaN  ...  1:17:00  1:33:01  1:48:31  2:03:38  0:04:59
#
#   Proj Time Official Time Overall Gender Division
# 0         -       2:09:37       1      1        1
# 1         -       2:09:58       2      2        2
# 2         -       2:10:28       3      3        3
#
# [3 rows x 25 columns]

# %%
marathon_2017.tail(n=4)
# Out:
#        Unnamed: 0    Bib                Name  Age M/F          City State  \
# 26406       26406  25178  Avelino, Andrew R.   25   M  Fayetteville    NC
# 26407       26407  27086     Hantel, Johanna   57   F       Malvern    PA
# 26408       26408  25268        Reilly, Bill   64   M      New York    NY
# 26409       26409  25266       Rigsby, Scott   48   M    Alpharetta    GA
#
#       Country Citizen Unnamed: 9  ...      25K      30K      35K      40K  \
# 26406     USA     NaN         MI  ...  3:50:19  4:50:01  5:53:48  6:54:21
# 26407     USA     NaN        NaN  ...  4:15:21  5:06:37  6:00:33  6:54:38
# 26408     USA     NaN         MI  ...  4:06:10  5:07:09  6:06:07  6:56:08
# 26409     USA     NaN         MI  ...  4:27:14  5:37:13  6:39:07  7:41:23
#
#           Pace Proj Time Official Time Overall Gender Division
# 26406  0:16:40         -       7:16:59   26408  14436     4774
# 26407  0:16:47         -       7:19:37   26409  11973      698
# ...

# %%
marathon_2017.sort_values(by=['Age']) # age값을 중심으로 오름차순
# Out:
#        Unnamed: 0    Bib                 Name  Age M/F           City State  \
# 17735       17735  26356      Fried, Lucas A.   18   M        Wayland    MA
# 22938       22938  28542     Blake, Meghan E.   18   F        Needham    MA
# 4735         4735   4496        Moore, Ryan D   18   M     North Bend    WA
# 5443         5443  27556      Umphrey, Duncan   18   M        Concord    MA
# 15919       15919  15125       Rucker, Alyssa   18   F         Durham    NC
# ...           ...    ...                  ...  ...  ..            ...   ...
# 21363       21363  25095     Miller, Gerald W   80   M        Calgary    AB
# 21983       21983  25123  Shimojou, Michiharu   81   M          Tokyo   NaN
# 25469       25469  25110     Roake, Samuel C.   81   M  San Francisco    CA
# 22619       22619  25134            Yoo, Jack   83   M        Chicago    IL
# 26340       26340  25269    Beiers, Katherine   84   F     Santa Cruz    CA
#
# ...

# %%
marathon_2017.sort_values(by=['Age'], ascending=False #age값을 기준으로 내림차순
# Out:
#        Unnamed: 0    Bib                  Name  Age M/F           City State  \
# 26340       26340  25269     Beiers, Katherine   84   F     Santa Cruz    CA
# 22619       22619  25134             Yoo, Jack   83   M        Chicago    IL
# 25469       25469  25110      Roake, Samuel C.   81   M  San Francisco    CA
# 21983       21983  25123   Shimojou, Michiharu   81   M          Tokyo   NaN
# 23413       23413  24818    Bobeldijk, Volkert   80   M       Pembroke    ON
# ...           ...    ...                   ...  ...  ..            ...   ...
# 16499       16499  30146        Canzano, James   18   M     Shrewsbury    MA
# 23251       23251  27454     Mahoney, Tyler S.   18   F      Holliston    MA
# 26328       26328  30353   MacDonald, Grace C.   18   F     Marblehead    MA
# 25459       25459  25946  Waring, Elizabeth L.   18   F         Newton    MA
# 15931       15931  30496    Pohl, Elizabeth S.   18   F         Weston    MA
#
# ...

# %%
marathon_2017.shape # 행,열 수
# Out:
# (26410, 25)

# %%
marathon_2017.describe()
# Out:
#          Unnamed: 0           Age       Overall        Gender      Division
# count  26410.000000  26410.000000  26410.000000  26410.000000  26410.000000
# mean   13204.500000     42.587732  13206.260091   6660.973230   1588.796706
# std     7624.054641     11.419467   7624.370496   3910.031525   1423.199500
# min        0.000000     18.000000      1.000000      1.000000      1.000000
# 25%     6602.250000     34.000000   6604.250000   3302.250000    502.000000
# 50%    13204.500000     43.000000  13206.500000   6603.500000   1154.000000
# 75%    19806.750000     51.000000  19808.750000   9904.750000   2190.750000
# max    26409.000000     84.000000  26411.000000  14438.000000   5846.000000

# %%
marathon_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26410 entries, 0 to 26409
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     26410 non-null  int64
#  1   Bib            26410 non-null  object
#  2   Name           26410 non-null  object
#  3   Age            26410 non-null  int64
#  4   M/F            26410 non-null  object
#  5   City           26410 non-null  object
#  6   State          22815 non-null  object
#  7   Country        26410 non-null  object
#  8   Citizen        1254 non-null   object
#  9   Unnamed: 9     91 non-null     object
#  10  5K             26410 non-null  object
#  11  10K            26410 non-null  object
#  12  15K            26410 non-null  object
#  13  20K            26410 non-null  object
#  14  Half           26410 non-null  object
#  15  25K            26410 non-null  object
#  16  30K            26410 non-null  object
# ...

# %%
marathon_2017['Age'] = marathon_2017['Age'].astype(str)
marathon_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26410 entries, 0 to 26409
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     26410 non-null  int64
#  1   Bib            26410 non-null  object
#  2   Name           26410 non-null  object
#  3   Age            26410 non-null  object
#  4   M/F            26410 non-null  object
#  5   City           26410 non-null  object
#  6   State          22815 non-null  object
#  7   Country        26410 non-null  object
#  8   Citizen        1254 non-null   object
#  9   Unnamed: 9     91 non-null     object
#  10  5K             26410 non-null  object
#  11  10K            26410 non-null  object
#  12  15K            26410 non-null  object
#  13  20K            26410 non-null  object
#  14  Half           26410 non-null  object
#  15  25K            26410 non-null  object
#  16  30K            26410 non-null  object
# ...

# %%
marathon_2017 = pd.read_csv("./marathon_results_2017.csv")
marathon_2017.head()
# Out:
#    Unnamed: 0 Bib              Name  Age M/F           City State Country  \
# 0           0  11   Kirui, Geoffrey   24   M       Keringet   NaN     KEN
# 1           1  17       Rupp, Galen   30   M       Portland    OR     USA
# 2           2  23     Osako, Suguru   25   M   Machida-City   NaN     JPN
# 3           3  21  Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA
# 4           4   9    Chebet, Wilson   31   M       Marakwet   NaN     KEN
#
#   Citizen Unnamed: 9  ...      25K      30K      35K      40K     Pace  \
# 0     NaN        NaN  ...  1:16:59  1:33:01  1:48:19  2:02:53  0:04:57
# 1     NaN        NaN  ...  1:16:59  1:33:01  1:48:19  2:03:14  0:04:58
# 2     NaN        NaN  ...  1:17:00  1:33:01  1:48:31  2:03:38  0:04:59
# 3     NaN        NaN  ...  1:17:00  1:33:01  1:48:58  2:04:35  0:05:03
# 4     NaN        NaN  ...  1:16:59  1:33:01  1:48:41  2:05:00  0:05:04
#
#   Proj Time Official Time Overall Gender Division
# ...

# %%
marathon_2017['Name']#자료형 Series
# Out:
#                            Name
# 0               Kirui, Geoffrey
# 1                   Rupp, Galen
# 2                 Osako, Suguru
# 3              Biwott, Shadrack
# 4                Chebet, Wilson
# ...                         ...
# 26405  Steinbach, Paula Eyvonne
# 26406        Avelino, Andrew R.
# 26407           Hantel, Johanna
# 26408              Reilly, Bill
# 26409             Rigsby, Scott
#
# [26410 rows x 1 columns]

# %%
marathon_2017[['Name','Age','M/F','City','Country']]
# Out:
#                            Name  Age M/F           City Country
# 0               Kirui, Geoffrey   24   M       Keringet     KEN
# 1                   Rupp, Galen   30   M       Portland     USA
# 2                 Osako, Suguru   25   M   Machida-City     JPN
# 3              Biwott, Shadrack   32   M  Mammoth Lakes     USA
# 4                Chebet, Wilson   31   M       Marakwet     KEN
# ...                         ...  ...  ..            ...     ...
# 26405  Steinbach, Paula Eyvonne   61   F        Ontario     USA
# 26406        Avelino, Andrew R.   25   M   Fayetteville     USA
# 26407           Hantel, Johanna   57   F        Malvern     USA
# 26408              Reilly, Bill   64   M       New York     USA
# 26409             Rigsby, Scott   48   M     Alpharetta     USA
#
# [26410 rows x 5 columns]

# %%
marathon_2017[['Name']]#자료형 DataFrame
# Out:
#                            Name
# 0               Kirui, Geoffrey
# 1                   Rupp, Galen
# 2                 Osako, Suguru
# 3              Biwott, Shadrack
# 4                Chebet, Wilson
# ...                         ...
# 26405  Steinbach, Paula Eyvonne
# 26406        Avelino, Andrew R.
# 26407           Hantel, Johanna
# 26408              Reilly, Bill
# 26409             Rigsby, Scott
#
# [26410 rows x 1 columns]

# %%
marathon_2017[:10] # 0~9까지의 row만 가져옴
# Out:
#    Unnamed: 0 Bib                Name  Age M/F              City State  \
# 0           0  11     Kirui, Geoffrey   24   M          Keringet   NaN
# 1           1  17         Rupp, Galen   30   M          Portland    OR
# 2           2  23       Osako, Suguru   25   M      Machida-City   NaN
# 3           3  21    Biwott, Shadrack   32   M     Mammoth Lakes    CA
# 4           4   9      Chebet, Wilson   31   M          Marakwet   NaN
# 5           5  15    Abdirahman, Abdi   40   M           Phoenix    AZ
# 6           6  63  Maiyo, Augustus K.   33   M  Colorado Springs    CO
# 7           7   7         Sefir, Dino   28   M       Addis Ababa   NaN
# 8           8  18      Puskedra, Luke   27   M            Eugene    OR
# 9           9  20         Ward, Jared   28   M         Kaysville    UT
#
#   Country Citizen Unnamed: 9  ...      25K      30K      35K      40K  \
# 0     KEN     NaN        NaN  ...  1:16:59  1:33:01  1:48:19  2:02:53
# ...

# %%
marathon_2017[7:10] # 7~9까지의 row만 가져옴
# Out:
#    Unnamed: 0 Bib            Name  Age M/F         City State Country Citizen  \
# 7           7   7     Sefir, Dino   28   M  Addis Ababa   NaN     ETH     NaN
# 8           8  18  Puskedra, Luke   27   M       Eugene    OR     USA     NaN
# 9           9  20     Ward, Jared   28   M    Kaysville    UT     USA     NaN
#
#   Unnamed: 9  ...      25K      30K      35K      40K     Pace Proj Time  \
# 7        NaN  ...  1:18:36  1:34:52  1:51:11  2:07:09  0:05:08         -
# 8        NaN  ...  1:17:26  1:34:05  1:50:53  2:07:17  0:05:09         -
# 9        NaN  ...  1:17:17  1:33:49  1:50:44  2:07:54  0:05:11         -
#
#   Official Time Overall Gender Division
# 7       2:14:26       8      8        7
# 8       2:14:45       9      9        8
# 9       2:15:28      10     10        9
#
# [3 rows x 25 columns]

# %%
import numpy as np
marathon_2017.index = np.arange(100,26510)

# %%
marathon_2017.head()
# Out:
#      Unnamed: 0 Bib              Name  Age M/F           City State Country  \
# 100           0  11   Kirui, Geoffrey   24   M       Keringet   NaN     KEN
# 101           1  17       Rupp, Galen   30   M       Portland    OR     USA
# 102           2  23     Osako, Suguru   25   M   Machida-City   NaN     JPN
# 103           3  21  Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA
# 104           4   9    Chebet, Wilson   31   M       Marakwet   NaN     KEN
#
#     Citizen Unnamed: 9  ...      25K      30K      35K      40K     Pace  \
# 100     NaN        NaN  ...  1:16:59  1:33:01  1:48:19  2:02:53  0:04:57
# 101     NaN        NaN  ...  1:16:59  1:33:01  1:48:19  2:03:14  0:04:58
# 102     NaN        NaN  ...  1:17:00  1:33:01  1:48:31  2:03:38  0:04:59
# 103     NaN        NaN  ...  1:17:00  1:33:01  1:48:58  2:04:35  0:05:03
# 104     NaN        NaN  ...  1:16:59  1:33:01  1:48:41  2:05:00  0:05:04
#
#     Proj Time Official Time Overall Gender Division
# ...

# %%
marathon_2017.loc[[103, 307, 509, 997]] # 103row 추출
# Out:
#      Unnamed: 0   Bib                 Name  Age M/F           City State  \
# 103           3    21     Biwott, Shadrack   32   M  Mammoth Lakes    CA
# 307         207   657    Hoogkamer, Wouter   35   M       Longmont    CO
# 509         409  2518       Manning, Aaron   23   M        Toronto    ON
# 997         897  3891  Feldman, William P.   31   M     Greensboro    NC
#
#     Country Citizen Unnamed: 9  ...      25K      30K      35K      40K  \
# 103     USA     NaN        NaN  ...  1:17:00  1:33:01  1:48:58  2:04:35
# 307     USA     NED        NaN  ...  1:32:01  1:51:16  2:11:21  2:31:59
# 509     CAN     NaN        NaN  ...  1:37:59  1:57:36  2:17:42  2:37:42
# 997     USA     NaN        NaN  ...  1:44:45  2:05:47  2:26:29  2:46:29
#
#         Pace Proj Time Official Time Overall Gender Division
# 103  0:05:03         -       2:12:08       4      4        4
# 307  0:06:09         -       2:41:03     208    186      161
# ...

# %%
marathon_2017.loc[[103, 307, 509, 997], ['Name', 'Age', 'M/F', 'City', 'Country']] # 103row 추출
# Out:
#                     Name  Age M/F           City Country
# 103     Biwott, Shadrack   32   M  Mammoth Lakes     USA
# 307    Hoogkamer, Wouter   35   M       Longmont     USA
# 509       Manning, Aaron   23   M        Toronto     CAN
# 997  Feldman, William P.   31   M     Greensboro     USA

# %%
marathon_2017.iloc[[0, 100, 200, 450], [2,3,4,5,7]] # 103row 추출
# Out:
#                 Name  Age M/F          City Country
# 100  Kirui, Geoffrey   24   M      Keringet     KEN
# 200  Stone, Chris C.   36   M      Edmonton     CAN
# 300    Burk, Bryan T   26   M  Spring Arbor     USA
# 550     Carney, Ryne   26   M    Washington     USA

# %%
#boolean selection 으로 row 선택해 가져오기

# %%
Country_ = (marathon_2017['Country'] == 'KOR')
Age_ = (marathon_2017['Age']>=30) & (marathon_2017['Age']<40)

marathon_2017[Country_ & Age_]
# Out:
#        Unnamed: 0    Bib            Name  Age M/F         City State Country  \
# 1437         1337    966    Shin, Kilsun   37   M        Seoul   NaN     KOR
# 5068         4968   1940  Kim, Jae Kwang   35   M  Gyeonggi-Do   NaN     KOR
# 14008       13908   3596   Lee, Hongwook   36   M        Busan   NaN     KOR
# 23319       23219  12785   Moon, Bo Youn   37   F        Seoul   NaN     KOR
#
#       Citizen Unnamed: 9  ...      25K      30K      35K      40K     Pace  \
# 1437      NaN        NaN  ...  1:45:13  2:06:46  2:28:02  2:49:32  0:06:50
# 5068      NaN        NaN  ...  1:44:29  2:09:00  2:41:10  3:09:37  0:07:42
# 14008     NaN        NaN  ...  2:08:05  2:38:04  3:09:16  3:40:28  0:08:56
# 23319     NaN        NaN  ...  2:34:31  3:11:53  3:54:03  4:35:06  0:11:06
#
#       Proj Time Official Time Overall Gender Division
# 1437          -       2:59:05    1338   1253      962
# 5068          -       3:21:28    4969   4232     2387
# ...

# %%
marathon_2017 = pd.read_csv('./marathon_results_2017.csv')
marathon_2017.head()
# Out:
#    Unnamed: 0 Bib              Name  Age M/F           City State Country  \
# 0           0  11   Kirui, Geoffrey   24   M       Keringet   NaN     KEN
# 1           1  17       Rupp, Galen   30   M       Portland    OR     USA
# 2           2  23     Osako, Suguru   25   M   Machida-City   NaN     JPN
# 3           3  21  Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA
# 4           4   9    Chebet, Wilson   31   M       Marakwet   NaN     KEN
#
#   Citizen Unnamed: 9  ...      25K      30K      35K      40K     Pace  \
# 0     NaN        NaN  ...  1:16:59  1:33:01  1:48:19  2:02:53  0:04:57
# 1     NaN        NaN  ...  1:16:59  1:33:01  1:48:19  2:03:14  0:04:58
# 2     NaN        NaN  ...  1:17:00  1:33:01  1:48:31  2:03:38  0:04:59
# 3     NaN        NaN  ...  1:17:00  1:33:01  1:48:58  2:04:35  0:05:03
# 4     NaN        NaN  ...  1:16:59  1:33:01  1:48:41  2:05:00  0:05:04
#
#   Proj Time Official Time Overall Gender Division
# ...

# %%
marathon_2017['Age_double'] = marathon_2017['Age'] * 2
marathon_2017.head()
# Out:
#    Unnamed: 0 Bib              Name  Age M/F           City State Country  \
# 0           0  11   Kirui, Geoffrey   24   M       Keringet   NaN     KEN
# 1           1  17       Rupp, Galen   30   M       Portland    OR     USA
# 2           2  23     Osako, Suguru   25   M   Machida-City   NaN     JPN
# 3           3  21  Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA
# 4           4   9    Chebet, Wilson   31   M       Marakwet   NaN     KEN
#
#   Citizen Unnamed: 9  ...      30K      35K      40K     Pace Proj Time  \
# 0     NaN        NaN  ...  1:33:01  1:48:19  2:02:53  0:04:57         -
# 1     NaN        NaN  ...  1:33:01  1:48:19  2:03:14  0:04:58         -
# 2     NaN        NaN  ...  1:33:01  1:48:31  2:03:38  0:04:59         -
# 3     NaN        NaN  ...  1:33:01  1:48:58  2:04:35  0:05:03         -
# 4     NaN        NaN  ...  1:33:01  1:48:41  2:05:00  0:05:04         -
#
#   Official Time Overall Gender Division Age_double
# ...

# %%
marathon_2017['Age_tripple'] = marathon_2017['Age_double'] + marathon_2017['Age']
marathon_2017.head()
# Out:
#    Unnamed: 0 Bib              Name  Age M/F           City State Country  \
# 0           0  11   Kirui, Geoffrey   24   M       Keringet   NaN     KEN
# 1           1  17       Rupp, Galen   30   M       Portland    OR     USA
# 2           2  23     Osako, Suguru   25   M   Machida-City   NaN     JPN
# 3           3  21  Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA
# 4           4   9    Chebet, Wilson   31   M       Marakwet   NaN     KEN
#
#   Citizen Unnamed: 9  ...      35K      40K     Pace Proj Time Official Time  \
# 0     NaN        NaN  ...  1:48:19  2:02:53  0:04:57         -       2:09:37
# 1     NaN        NaN  ...  1:48:19  2:03:14  0:04:58         -       2:09:58
# 2     NaN        NaN  ...  1:48:31  2:03:38  0:04:59         -       2:10:28
# 3     NaN        NaN  ...  1:48:58  2:04:35  0:05:03         -       2:12:08
# 4     NaN        NaN  ...  1:48:41  2:05:00  0:05:04         -       2:12:35
#
#   Overall Gender Division Age_double Age_tripple
# ...

# %%
marathon_2017.insert(29, 'Address', marathon_2017['Country'] + ' ' + marathon_2017['City'])
marathon_2017.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14648\2007457863.py in <module>
# ----> 1 marathon_2017.insert(29, 'Address', marathon_2017['Country'] + ' ' + marathon_2017['City'])
#       2 marathon_2017.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    4441         if not allow_duplicates and column in self.columns:
#    4442             # Should this be a different kind of error??
# -> 4443             raise ValueError(f"cannot insert {column}, already exists")
#    4444         if not isinstance(loc, int):
#    4445             raise TypeError("loc must be int")
#
# ValueError: cannot insert Address, already exists
